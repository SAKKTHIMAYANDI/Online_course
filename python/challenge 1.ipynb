# %%
#1
print('sakkthi')
print('43/6 colonymanner,salem-636006')
# Out:
# sakkthi
# 43/6 colonymanner,salem-636006

# %%
#2
a = input("Enter the Name:")
print('Hello',a)
# Out:
# Enter the Name:Sakkthi
# Hello Sakkthi

# %%
#3
radius = float(input('Enter the radius value:'))
area = 3.14 * radius * radius
circum = 2 * 3.14 * radius
print('Display the area values:',area)
print('Display the circum values:',circum)
# Out:
# Enter the radius value:25
# Display the area values: 1962.5
# Display the circum values: 157.0

# %%
#4
Length = float(input('Enter the length value:'))
Breadth = float(input('Enter the breadth value:'))
area = Length * Breadth
perimeter = (2 * (Length + Breadth))
print('Area of Length and Breadth =',area)
print('Perimeter of Length and Breadth = ',perimeter)
# Out:
# Enter the length value:9
# Enter the breadth value:4
# Area of Length and Breadth = 36.0
# Perimeter of Length and Breadth =  26.0

# %%
#5
side = float(input('Enter the side of a square:'))
area = side * side
perimeter = 4 * side
print('Area of square =',area)
print('perimeter of square =',perimeter)
# Out:
# Enter the side of a square:9
# Area of square = 81.0
# perimeter of square = 36.0

# %%
#6
Fahrenheit = float(input('Enter the Fahrenheit value:'))
Centigrade = ((Fahrenheit-32)*(5/9))
print('Centigrade of Fahrenheit:',Centigrade)
# Out:
# Enter the Fahrenheit value:89.6
# Centigrade of Fahrenheit: 32.0

# %%
#7
#addition
a = complex(input('Enter the complex value a:'))
b = complex(input('Enter the complex value b:'))
c = a + b
print('Disaply the a & b complex value in c:',c)
# Out:
# Enter the complex value a:10+4j
# Enter the complex value b:6+2j
# Disaply the a & b complex value in c: (16+6j)

# %%
#subtraction
a = complex(input('Enter the complex value a:'))
b = complex(input('Enter the complex value b:'))
c = a - b
print('Disaply the a & b complex value in c:',c)
# Out:
# Disaply the a & b complex value in c: (4+2j)

# %%
#multiplication
a = complex(input('Enter the complex value a:'))
b = complex(input('Enter the complex value b:'))
c = a * b
print('Disaply the a & b complex value in c:',c)
# Out:
# Enter the complex value a:10+4j
# Enter the complex value b:6+2j
# Disaply the a & b complex value in c: (52+44j)

# %%
#8
Name = str(input('Enter the user name:'))
Salary = float(input('Enter the basic salary amount:'))
drearness = float(Salary*0.40)
house = float(Salary*0.20)
gross = Salary + drearness + house
print('drearness allowance =',drearness)
print('house rent allowance =',house)
print('gross salary:',gross)
# Out:
# Enter the user name:sakkthi
# Enter the basic salary amount:10000
# drearness allowance = 4000.0
# house rent allowance = 2000.0
# gross salary: 16000.0

# %%
#9
n = int(input('Enter the integers value:'))
sum = int((n*(n+1))/2)
print('Display the value:',sum)
# Out:
# Enter the integers value:2
# Display the value: 3

# %%
#10 #a
a = int(input('Enter the a value:'))
b = int(input('Enter the b value:'))
c = a + b
print('Display the c values=',c)
# Out:
# Enter the a value:10
# Enter the b value:20
# c= 30

# %%
# subtraction
c = b - a 
print('Display the c value =',c)
# Out:
# Display the c value = 10

# %%
#multiplcation
c = a * b
print('Display the c value =',c)
# Out:
# Display the c value = 200

# %%
#divided & quotient
c = a // b
print('Display the c value =',c)
# Out:
# Display the c value = 0

# %%
#divided & remainder
c = a % b
print('Display the c value =',c)
# Out:
# Display the c value = 10

# %%
#multiple
c = a ** b
print('Display the c value =',c)
# Out:
# Display the c value = 100000000000000000000
