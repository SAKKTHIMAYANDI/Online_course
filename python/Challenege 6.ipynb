# %%
#1 
a = input('Enter the txt values : ')
f = open(a,'r')
c = f.readlines()
for i in c:
    print(i)
    
f.close()
# Out:
# Enter the txt values : D:\python\sa.txt
# {"Name": "Sakthi", "Age": 21, "10th percent": 56.8, "12th percent": 44}

# %%
#2
import file

n = input('Enter the name of files: ')

print('Display the values : ',file.size(n))
# Out:
# Enter the name of files: week 6.ipynb
# Display the values :  (21.4599609375, 'KB')

# %%
#3
source1 = input('Enter the file name source1 : ')

b = open(source1,'r')
c = open(source1,'w')
while True:
    data = b.read(1)
    if data == '':
        break
        
    c.write(data)
    
b.close()
c.close()
# Out:
# Enter the file name source1 : D:\python\sam.txt

# %%
#4
var = input('Enter the file name: ')
f = open(var,'r')
l = f.readlines()
for i in l:
    print(i)
    
f.close()
# Out:
# Enter the file name: D:\python\sam.txt
# mayandi boys
#
# mayakama kalakama
#
# {"Name": "Sakthi", "Age": 21, "10th percent": 56.8, "12th percent": 44}

# %%
#5

source1 = input('Enter the file name source1 : ')
source2 = input('Enter the file name source2 : ')

b = open(source1,'r')
c = open(source2,'w')
while True:
    data = b.read(1)
    if data == '':
        break
        
    c.write(data)
    
b.close()
c.close()

# %%
#6
source1 = input('Enter the file name source1 : ')
source2 = input('Enter the file name source2 : ')

b = open(source1,'r')
c = open(source2,'a')
while True:
    data = b.read(1)
    if data == '':
        break
        
    c.write(data)
    
b.close()
c.close()

# %%
#7

user = input('Enter the file name: ')
f = open(user,'r')
l = f.readlines()
l.sort()
for i in l:
    print(i)
    
f.close()
# Out:
# Enter the file name: D:\mala.txt
# ashok	55
#
# fazel	5
#
# mala	20
#
# sakthi	25

# %%
#8
import m1
import m2
import m3

a = int(input('Enter the a values: '))
b = int(input('Enter the b values: '))
print('a + b = ',m1.f1(a,b))
print('a * b = ',m2.f2(a,b))
print('a / b = ',m3.f3(a,b))
# Out:
#  Display the m1 part
#
#  Dispaky the m2 part
#
#  Display the m3 part
# Enter the a values: 10
# Enter the b values: 2
# a + b =  12
# a * b =  20
# a / b =  5.0

# %%
#9

def fun1(a,b):
    return a+b
def fun2(a,b):
    return a/b
def fun3(a,b):
    return a-b

if __name__ == '__main__':
    fun1(10,2)
    fun2(10,2)
    fun3(10,2)

# %%
import mod
import mod.py import f1
import mod.py import f2
import mod.py import f3
from mod.py import f1,f2,f3
